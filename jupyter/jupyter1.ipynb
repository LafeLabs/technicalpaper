# %% [markdown]
# # Jupyter Notebook
#
# Here are some random examples of Jupyter notebook elements which demonstrate some functionalities.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([0, 1, 2, 3, 4], [0, 3, 5, 9, 11])
plt.xlabel('x')
plt.ylabel('y')
plt.savefig('../figures/python_figure1.png')

# %%
x = np.linspace(-10,10,100)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)
plt.xlabel('t')
plt.ylabel('V')
plt.savefig('../figures/python_figure1.svg')
